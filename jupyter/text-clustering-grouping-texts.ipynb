# %% [markdown]
# <a href="https://www.kaggle.com/code/leomauro/text-clustering-grouping-texts?scriptVersionId=90736833" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Text Clustering - Grouping Texts
#
# This notebook presents a simple way to clustering similar texts based on [Levenshtein distance](https://en.wikipedia.org/wiki/Levenshtein_distance). "Levenshtein distance is a string metric for measuring the difference between two sequences" (Wikipedia). We are going to experiment with a text clustering strategy in [Fake Names](http://listofrandomnames.com/) and [Medium Articles](https://www.kaggle.com/hsankesara/medium-articles). In the end, I hope you are going to be able to execute your own text clustering experiments.
#
# > **Summary** - Text Clustering using Levenshtein distance (similarity).
# > Content for intermediate level in Machine Learning and Data Science!
#
# # Table of Contents
#
# > **Note** - Some codes and outputs are hidden, to highlight the most important content.
#
# The notebook is organized as:
#
# 1. [Data Exploration](#data)
# 1. [Text Clustering](#cluster)
#    - [Levenshtein Distance](#lev)
#    - [Clustering](#clus)
# 1. [References](#ref)

# %% [markdown]
# -----
# <a id="data"></a>
# # Data Exploration
#
# Data loading and data samples. I'm just creating two datasets to experiment the clustering.
# - Fake Names
# - Medium Articles

# %%
# standard libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## Fake Names
#
# We simply have to generate a list of 300 fake names using http://listofrandomnames.com/. Also, create a short list with only 26 names.

# %%
names = ['Tashia Monsen', 'Marcy Sondag', 'Kristine Wool', 'Shantay Cubbage', 'Duncan Albano', 'Dollie Everhart', 'Sherryl Funston', 'Cherly Gooding', 'Elois Lasch', 'Irina Temme', 'Candis Sievert', 'Kris Difilippo', 'Rosana Bocanegra', 'Ernestina Thacker', 'Terrilyn Antonio', 'Maxwell Kin', 'Gilberte Laxton', 'Roberto Pavone', 'Alanna Hervey', 'Orlando Heit', 'Brianna Cutshall', 'Eveline Alvidrez', 'Rick Benes', 'Leann Shimer', 'Josie Witcher', 'Lissette Imburgia', 'Candra Coloma', 'Denis Eldreth', 'Alfred Sue', 'Stevie Brannan', 'Lou Derouin', 'Missy Helman', 'Crissy Mejorado', 'Pamila Villegas', 'Carmella Waren', 'Shondra Kyles', 'Ashely Utley', 'Kenya Bottomley', 'Tiara Ball', 'Elza Starke', 'Linsey Howley', 'Caridad Wensel', 'Armanda Burmeister', 'Rosalba Zuber', 'Briana Eggleton', 'Keli Zelinski', 'Elena Hewlett', 'Asia Richburg', 'Ida Gerena', 'Corrina Weingarten', 'Nery Dewall', 'Aurore Boeke', 'Bok Yaeger', 'Phebe Stotz', 'Debbi Budde', 'Lionel Gartner', 'Danny Tusa', 'Dori Schrimsher', 'Cole Rando', 'Gladys Woolley', 'Micheal Derr', 'Kyoko Bryne', 'Lane Ditty', 'Eileen Klink', 'Antone Sturgeon', 'Chantelle Howerton', 'Siu Hendricks', 'Florrie Sears', 'Maryetta Gutierez', 'Vasiliki Borgmann', 'Eura Lovins', 'Bette Beech', 'Dino Pasko', 'Esther Margulies', 'Crissy Behar', 'Keesha Landau', 'Sean Grainger', 'Gaynell Sease', 'Maryellen Felps', 'Delmer Briles', 'Margurite Depriest', 'Bettye Shaikh', 'Denna Lawton', 'Janet Roark', 'Catrice Ruzicka', 'Marx Sing', 'Billie Shewmaker', 'Darla Mathew', 'Micheline Theisen', 'Rosenda Plum', 'Amee Hippler', 'Johnna Stickel', 'Shirely Tennison', 'Ossie Shadwick', 'Tarra Winton', 'Lincoln Burket', 'Lovie Wiesner', 'Chloe Eyler', 'Olene Groves', 'Ashely Blades', 'Mahalia Breazeale', 'Lavinia Agudelo', 'Lessie Westbrooks', 'Kenda Isenberg', 'Dianne Trumble', 'Elsie Legree', 'Louetta Delucca', 'Hattie Cozad', 'Roderick Kirklin', 'Paola Lagunas', 'Janiece Christain', 'Mayme Shoulders', 'Rolland Oxley', 'Brittani Buttery', 'Rosalia Difalco', 'Philip Leroux', 'Therese Mroz', 'Georgette Chacon', 'Gaynell Mumm', 'Arminda Flannery', 'Stella Peeples', 'Stevie Hardesty', 'Edyth Glotfelty', 'Jama Gervais', 'Kaye Pariseau', 'Albertha Furby', 'Jenine Gephart', 'Isidra Below', 'Ethelene Lesage', 'Soraya Hardcastle', 'Oralee Bussiere', 'Latisha Mcmurry', 'Rosemary Mauldin', 'Michiko Fu', 'Marshall Giblin', 'Trent Tong', 'Laureen Vives', 'Janett Cecere', 'Clarisa Allain', 'Stefania Frigo', 'Anastacia Cypert', 'Emmett Forward', 'Bettina Gong', 'Jenise Longstreet', 'Dick Carranza', 'Valentin Hearn', 'Genna Sera', 'Signe Coster', 'Pearlene Yant', 'Karine Twining', 'Olive Whaley', 'Mathilda Tomasi', 'Terrilyn Panos', 'Malia Brandy', 'Stanley Molnar', 'Melvin Sutterfield', 'Dianna Roney', 'Lola Skoglund', 'Mitchell Snelgrove', 'Julian Schrum', 'Evelynn Messing', 'Shaunta Chon', 'Mica Coate', 'Christene Ingerson', 'Karolyn Grasty', 'Josphine Horiuchi', 'Jesica Kerns', 'Osvaldo Roush', 'Omega Lena', 'Selena Garlington', 'Karena Kitchell', 'Ouida Stampley', 'Jarrett Decola', 'Susan Stage', 'Kena Kmetz', 'Denita Houghton', 'Marylou Ashman', 'Frank Bellard', 'Shanae Cassella', 'Ashley Burleson', 'Raisa Keck', 'Latia Houck', 'Vergie Hunte', 'Phylicia Meiers', 'Rigoberto Holton', 'Nelson Rohan', 'Loraine Christensen', 'Xiomara Whittingham', 'Tory Prisco', 'Kaleigh Amezcua', 'Carlo Marlowe', 'Adriene Adger', 'Delsie Contreras', 'Vertie Nardone', 'Lynelle Roder', 'Leatha Mccary', 'Bobette Baran', 'Yanira Mau', 'Carma Jung', 'Daysi Belin', 'William Pinard', 'Demetria Collins', 'Randi Levar', 'Hunter Surette', 'Hosea Degner', 'Zelma Appling', 'Nicola Byam', 'Kai Coomes', 'Signe Lavergne', 'Lan Wasko', 'Scott Simoneaux', 'Briana Maclin', 'Tresa Cullison', 'Catarina Presley', 'Justine Chou', 'Gabriel Hammonds', 'Al Hickel', 'Eura Coto', 'Piedad Cureton', 'Daron Muise', 'Cassey Randolph', 'Jodie Hansley', 'Theressa Marciniak', 'Dwana Talamantez', 'Nathanael Lemley', 'Clotilde Labelle', 'Wanda Patman', 'Cammy Lemieux', 'Jeraldine Small', 'Carlota Settle', 'Reva Kinyon', 'Miyoko Beckmann', 'Geraldo Lapoint', 'Caterina Spells', 'Zane Rosecrans', 'Micki Bosque', 'Quinn Loar', 'Ozella Kamerer', 'Yanira Evangelista', 'Gloria Bodner', 'Bree Gillard', 'Isidra Jakes', 'Sherwood Umland', 'Shery Brinn', 'Leona Stiner', 'Derek Szczepanski', 'Garnet Stoodley', 'Gracie Acres', 'Anneliese Yoshimoto', 'Paulene Dora', 'Werner Kerfoot', 'Venus Makuch', 'Columbus Nastasi', 'Shala Croteau', 'Johanne Stam', 'Ranee Wardwell', 'Mitsue Lentine', 'Elyse Escobar', 'Mayola Hiltz', 'Ione Helbing', 'Ming Atnip', 'Germaine Mclawhorn', 'Devin Elkin', 'Calvin Whisenant', 'Lai Glavin', 'Antonina Fernald', 'Fabiola Fahie', 'Paulene Hilyard', 'Nakia Jack', 'Janie Arwood', 'Thi Staples', 'Jaimee Garceau', 'Tana Mera', 'Alexa Eddy', 'Maribel Seguin', 'Beula Clement', 'Janette Mcniff', 'Jaleesa Nyman', 'Barbar Brueggemann', 'Ruthie Petrick', 'Cassy Niemeyer', 'Trina Gaudette', 'Sal Gabourel', 'Ji Reinhart', 'Abby Kump', 'Lucinda Aten', 'Minh Brumfield', 'Eladia Hiler', 'Exie Scholes', 'Cordelia Ott', 'Junita Osburn', 'Sparkle Leedy', 'Odell Castiglia', 'Randal Levalley', 'Tish Mccarthy', 'Stephen Lombardi', 'Elvin Reppert', 'Edgardo Prendergast', 'Arianne Wass', 'Viva Brake']
few_names = ['Arianne Wass', 'Jeraldine Small', 'Justine Chou', 'Kris Difilippo', 'Kristine Wool', 'Gabriel Hammonds', 'Georgette Chacon', 'Gilberte Laxton', 'Rigoberto Holton', 'Roberto Pavone', 'Vertie Nardone', 'Asia Richburg', 'Dori Schrimsher', 'Jodie Hansley', 'Josie Witcher', 'Josphine Horiuchi', 'Lovie Wiesner', 'Briana Eggleton', 'Briana Maclin', 'Brianna Cutshall', 'Brittani Buttery', 'Marshall Giblin', 'Rosemary Mauldin', 'Theressa Marciniak', 'Tresa Cullison', 'Yanira Evangelista']

# %%
from random import sample

print('Samples:', sample(names,3))
# Out:
# Samples: ['Maryetta Gutierez', 'Duncan Albano', 'Germaine Mclawhorn']

# %% [markdown]
# ## Medium Articles
#
# We are going to use a dataset called [Medium Articles](https://www.kaggle.com/hsankesara/medium-articles), which has of over 300 articles related Machine Learning, Artificial Intelligence, and Data Science areas.

# %%
# display files
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/medium-articles/articles.csv

# %%
df = pd.read_csv('/kaggle/input/medium-articles/articles.csv')
df.sample(3)
# Out:
#                   author claps  reading_time  \
# 5          Irhum Shafkat    2K            15
# 287              Wallarm    72             4
# 208  Eugenio Culurciello  6.4K             8
#
#                                                   link  \
# 5    https://towardsdatascience.com/intuitively-und...
# 287  https://lab.wallarm.com/tensorflow-dataset-api...
# 208  https://towardsdatascience.com/the-fall-of-rnn...
#
#                                                  title  \
# 5    Intuitively Understanding Convolutions for Dee...
# 287  TensorFlow Dataset API for increasing training...
# 208      The fall of RNN / LSTM – Towards Data Science
#
#                                                   text
# 5    The advent of powerful and versatile deep lear...
# 287  Wallarm AI engine is the heart of our security...
# 208  We fell for Recurrent neural networks (RNN), L...

# %%
# preprocess the medium titles
# - remove special characters
import re
import unidecode

medium = df['title'].str.lower()
medium = medium.apply(unidecode.unidecode)
medium = medium.apply(lambda x: re.sub(' +', ' ', x))

# %% [markdown]
# -----
# <a id="cluster"></a>
# # Text Clustering
#
# Let's define our clustering algorithm.
# - We have to compute the Levenshtein similarity
# - Further, we apply the Affinity Propagation Clustering algorithm to combine the texts
#
# **Why** do I choose Levenshtein and Affinity Propagation?
# - Levenshtein is a simple distance algorithm that can be used in word-level or character-level. Thus, it can handle different types of text; that is going to be better explained later with samples.
# - [Affinity Propagation](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AffinityPropagation.html) finds the ideal number of clusters and also an exemplar per cluster. This exemplar is like a centroid or the best example of the cluster. However, Affinity Propagation cannot handle properly with many texts (_e.g.,_ over five thousand) causing some inconsistent and weird clusters.

# %%
# %%capture
# !pip install Distance

# %%
import distance
from sklearn.cluster import AffinityPropagation

# %% [markdown]
# <a id="lev"></a>
# ## Levenshtein Distance
#
# First, we have to create our Levenshtein similarity. I also propose a Weighted Levenshtein similarity, based on the text length, just for experimentation.

# %%
def levenshtein(texts):
    '''
    Levenshtein Distance
    - It requires negative similarities, so -1 * levenshtein(t1, t2)
    '''
    texts = np.asarray(texts, dtype=object)
    _similarity = np.array([[distance.levenshtein(list(w1),list(w2)) for w1 in texts] for w2 in texts])
    _similarity = -1*_similarity
    return _similarity

# %%
# Levenshtein in character-level
texts = ['Lion', 'Leon']

levenshtein(texts)
# Out:
# array([[ 0, -1],
#        [-1,  0]])

# %%
# Levenshtein in word-level
texts = [
    ['hi', 'my', 'name', 'is'], 
    ['hello', 'my', 'surname', 'is']]

levenshtein(texts)
# Out:
# array([[ 0, -2],
#        [-2,  0]])

# %% [markdown]
# <a id="clus"></a>
# ## Clusteing
#
# At last, we can define our Text Clustering algorithm, using a similarity function and the Affinity Propagation for the clustering.
#
# Also, I defined a `word_level` parameter to say whether we have to compute in character-level or compute in word-level. It is recommended compute in word-level when you have a lot of long texts that usually have similar words. Thus, you uses word-level to compare texts by words instead of characters. For example, we are going to use character-level in fake names, and word-level in Medium texts.

# %%
def text_clustering(texts, similarity=levenshtein, word_level=False):
    '''Text Clustering'''
    # similarity
    if word_level: texts = [t.split() for t in texts]
    _similarity = levenshtein(texts)
    _affprop = AffinityPropagation(affinity="precomputed", damping=0.5, verbose=True,
        random_state=0, max_iter=1_000, convergence_iter=10)
    _affprop.fit(_similarity)
    return _affprop, _similarity


def print_clusters(affprop, texts):
    '''Print clusters'''
    texts = np.asarray(texts)
    clusters = np.unique(affprop.labels_)
    print(f'\n~ Number of texts:: {texts.shape[0]}')
    print(f'~ Number of clusters:: {clusters.shape[0]}')
    if clusters.shape[0] < 2: return 'Only few clusters - Stopped'
    for cluster_id in clusters:
        exemplar = texts[affprop.cluster_centers_indices_[cluster_id]]
        cluster = np.unique(texts[np.nonzero(affprop.labels_==cluster_id)])
        cluster_str = '";\n  "'.join(cluster)
        print(f'\n# Cluster ({cluster_id}) with ({len(cluster)}) elements')
        print(f'Exemplar:: {exemplar}')
        print(f'\nOthers::\n  "{cluster_str}"')

# %% [markdown]
# ### Fake Name
#
# Using only a set of 26 fake names.

# %%
# using only a set of 26 fake names
texts = few_names
affprop, _ = text_clustering(texts, similarity=levenshtein)
print_clusters(affprop, texts)
# Out:
# Converged after 12 iterations.
#
# ~ Number of texts:: 26
# ~ Number of clusters:: 4
#
# # Cluster (0) with (5) elements
# Exemplar:: Kristine Wool
#
# Others::
#   "Arianne Wass";
#   "Jeraldine Small";
#   "Justine Chou";
#   "Kris Difilippo";
#   "Kristine Wool"
#
# # Cluster (1) with (6) elements
# Exemplar:: Gilberte Laxton
#
# Others::
#   "Gabriel Hammonds";
#   "Georgette Chacon";
#   "Gilberte Laxton";
#   "Rigoberto Holton";
#   "Roberto Pavone";
#   "Vertie Nardone"
#
# # Cluster (2) with (6) elements
# Exemplar:: Josie Witcher
#
# Others::
#   "Asia Richburg";
#   "Dori Schrimsher";
#   "Jodie Hansley";
#   "Josie Witcher";
#   "Josphine Horiuchi";
#   "Lovie Wiesner"
#
# # Cluster (3) with (9) elements
# Exemplar:: Briana Maclin
#
# Others::
#   "Briana Eggleton";
#   "Briana Maclin";
#   "Brianna Cutshall";
#   "Brittani Buttery";
#   "Marshall Giblin";
#   "Rosemary Mauldin";
#   "Theressa Marciniak";
#   "Tresa Cullison";
#   "Yanira Evangelista"

# %% [markdown]
# #### Discussion
#
# Let's analyze the cluster results. **Notes:**
#
# - The algorithm was able to find four (4) clusters in 26 fake names.
# - We compare the texts using character-level, thereby comparing each character.
#
# The most simple way to analyze each cluster is: "compare the examplar with the others". So, lets' do that.
#
# **Cluster 0**
# - Exemplar: `Kristine Wool`
# - Notes:
#    1. names ending with 'ne'
#    1. names starting with 'Kris'
#    1. surnames ending with 'ol', 'o' or 'l'
#    1. surnames starting with 'W'
#
# **Cluster 1**
# - Exemplar: `Gilberte Laxton`
# - Notes:
#    1. names ending with 'te'
#    1. names starting with 'G'
#    1. names with 'l', 'ert' in the middle
#    1. surnames ending, or close of the ending, with 'on'
#    1. surnames with 'a' in the second character
#
# **Cluster 2**
# - Exemplar: `Josie Witcher`
# - Notes:
#    1. names ending with 'ie', 'ia', or 'i'
#    1. names starting with 'Jo' or 'Lo'
#    1. surnames ending with 'er'
#    1. surnames starting with 'W' or 'Wi'
#    1. 'Asia Richburg' looks weird here
#
# **Cluster 3**
# - Exemplar: `Briana Maclin`
# - Notes:
#    1. names with 'Briana'
#    1. names ending with 'na' or 'a'
#    1. names starting with 'Br'
#    1. surnames ending with 'in' or 'on'
#    1. surnames starting with 'Ma'
#    1. 'Yanira Evangelista' looks weird here
#
# Thus, we can see pretty nice results, in general. However, we find some names that are different from the examplar - this can happend due many reasons, like: (1) this name is similar to another name in the cluster, (2) test differents `damping` values in Affinity Propagation algorithm, or (3) try to modify the Levenshtein metric.

# %% [markdown]
# ### Medium Articles
#
# #### Word-Level Analysis

# %%
texts = medium
affprop, _ = text_clustering(texts, similarity=levenshtein, word_level=True)
print_clusters(affprop, texts)
# Out:
# Converged after 90 iterations.
#
# ~ Number of texts:: 337
# ~ Number of clusters:: 75
#
# # Cluster (0) with (2) elements
# Exemplar:: machine learning: how to go from zero to hero - freecodecamp
#
# Others::
#   "a brief history of cnns in image segmentation: from r-cnn to mask r-cnn";
#   "machine learning: how to go from zero to hero - freecodecamp"
#
# # Cluster (1) with (2) elements
# Exemplar:: what i learned from interviewing at multiple ai companies and start-ups
#
# Others::
#   "what are the best intelligent chatbots or ai chatbots available online?";
#   "what i learned from interviewing at multiple ai companies and start-ups"
#
# # Cluster (2) with (1) elements
# Exemplar:: deep learning is going to teach us all the lesson of our lives: jobs are for machines
#
# Others::
#   "deep learning is going to teach us all the lesson of our lives: jobs are for machines"
#
# # Cluster (3) with (1) elements
# Exemplar:: machine learning is fun! part 3: deep learning and convolutional neural networks
#
# Others::
#   "machine learning is fun! part 3: deep learning and convolutional neural networks"
#
# # Cluster (4) with (3) elements
# Exemplar:: machine learning is fun! part 4: modern face recognition with deep learning
#
# Others::
#   "machine learning is fun part 6: how to do speech recognition with deep learning";
#   "machine learning is fun! part 4: modern face recognition with deep learning";
#   "write an ai to win at pong from scratch with reinforcement learning"
#
# # Cluster (5) with (10) elements
# Exemplar:: machine learning is fun! part 2 - adam geitgey - medium
#
# Others::
#   "1000x faster spelling correction algorithm (2012) - wolf garbe - medium";
#   "ai is coming, and it will be boring - denny vrandecic - medium";
#   "machine learning exercises in python, part 1 - john wittenauer - medium";
#   "machine learning is fun! - adam geitgey - medium";
#   "machine learning is fun! part 2 - adam geitgey - medium";
#   "no ui is the new ui - the startup - medium";
#   "tensorflow tutorial -- part 2 - illia polosukhin - medium";
#   "using oob tags in aiml: part i - pandorabots-blog - medium";
#   "what is "q" from a laymen... - coinmonks - medium";
#   "why natural search is awesome and how we got here - the vanguard - medium"
#
# # Cluster (6) with (4) elements
# Exemplar:: artificial intelligence -- the revolution hasn't happened yet
#
# Others::
#   "artificial intelligence -- the revolution hasn't happened yet";
#   "artificial intelligence top 10 articles -- june 2018";
#   "facebook m -- the anti-turing test - arik's blog";
#   "tensorflow in a nutshell -- part three: all the models"
#
# # Cluster (7) with (1) elements
# Exemplar:: Jian Yi De Cheng Xu Yuan Xue Xi ldaSuan Fa De Bu Zou - Zheng Qi Yu Mo Fa
#
# Others::
#   "Jian Yi De Cheng Xu Yuan Xue Xi ldaSuan Fa De Bu Zou - Zheng Qi Yu Mo Fa "
#
# # Cluster (8) with (2) elements
# Exemplar:: netflix recommendations: beyond the 5 stars (part 1)
#
# Others::
#   "netflix recommendations: beyond the 5 stars (part 1)";
#   "netflix recommendations: beyond the 5 stars (part 2)"
#
# # Cluster (9) with (14) elements
# Exemplar:: emotional computing - robbie tilton - medium
#
# Others::
#   "73 mind-blowing implications of a driverless future";
#   "announcing poncho the weatherbot - render-from-betaworks";
#   "c# plays bejeweled blitz - idanscott - medium";
#   "comparing artificial artists - kyle mcdonald - medium";
#   "digital companionship - matt wiese - medium";
#   "emotional computing - robbie tilton - medium";
#   "everyday ia - louis rosenfeld - medium";
#   "explaining the wolfram language - chris jagers - medium";
#   "from ballerina to ai researcher: part i - buzzrobot";
#   "modeling madly - data engineering - medium";
#   "reflections of "her" - e.c. mccarthy - medium";
#   "software 2.0 - andrej karpathy - medium";
#   "start automating your business tasks with slack - howdy";
#   "taking keras to the zoo - gab41"
#
# # Cluster (10) with (3) elements
# Exemplar:: the current state of machine intelligence - shivon zilis - medium
#
# Others::
#   "the current state of machine intelligence - shivon zilis - medium";
#   "the evolving role of business analytics - frank diana - medium";
#   "the state of artificial intelligence in six visuals"
#
# # Cluster (11) with (2) elements
# Exemplar:: the unreasonable effectiveness of random forests - rants on machine learning - medium
#
# Others::
#   "the unreasonable effectiveness of random forests - rants on machine learning - medium";
#   "what to do with "small" data? - rants on machine learning - medium"
#
# # Cluster (12) with (1) elements
# Exemplar:: machine learning eriiyn`aair, ruuaipthMaaaim - o v e r f i t t e d - medium
#
# Others::
#   "machine learning eriiyn`aair, ruuaipthMaaaim - o v e r f i t t e d - medium"
#
# # Cluster (13) with (1) elements
# Exemplar:: machine learning is fun part 5: language translation with deep learning and the magic of sequences
#
# Others::
#   "machine learning is fun part 5: language translation with deep learning and the magic of sequences"
#
# # Cluster (14) with (9) elements
# Exemplar:: deep learning the stock market - tal perry - medium
#
# Others::
#   "'her' is our space odyssey. - jorge camacho - medium";
#   "algorithms of the mind - deep learning 101 - medium";
#   "deep learning achievements over the past year - stats and bots";
#   "deep learning the stock market - tal perry - medium";
#   "self-driving cars and the trolley problem - tanay jaipuria - medium";
#   "understanding lstm and its diagrams - ml review - medium";
#   "using deep q-learning in fifa 18 to perfect the art of free-kicks";
#   "why ai research loves pac-man - tommy thompson - medium";
#   "will all musicians become robots? - roland trimmel - medium"
#
# # Cluster (15) with (5) elements
# Exemplar:: yes you should understand backprop - andrej karpathy - medium
#
# Others::
#   "building a smarter home feed - pinterest engineering - medium";
#   "data mining -- handling missing values the database - developerzen";
#   "obama-rnn -- machine generated political speeches. - samim - medium";
#   "website morphing and more revolutions in marketing - arjan haring - medium";
#   "yes you should understand backprop - andrej karpathy - medium"
#
# # Cluster (16) with (7) elements
# Exemplar:: machine learning in a year - learning new stuff - medium
#
# Others::
#   "a beginner's guide to ai/ml - machine learning for humans - medium";
#   "architecting a machine learning system for risk - airbnb engineering & data science - medium";
#   "learning how to code neural networks - learning new stuff - medium";
#   "machine learning in a week - learning new stuff - medium";
#   "machine learning in a year - learning new stuff - medium";
#   "of comets and gods in the making - thaddeus howze - medium";
#   "why turing's legacy demands a smarter keyboard - dr ben medlock - medium"
#
# # Cluster (17) with (1) elements
# Exemplar:: i interviewed at five top companies in silicon valley in five days, and luckily got five job offers
#
# Others::
#   "i interviewed at five top companies in silicon valley in five days, and luckily got five job offers"
#
# # Cluster (18) with (2) elements
# Exemplar:: the mind-blowing ai announcement from google that you probably missed.
#
# Others::
#   "the mind-blowing ai announcement from google that you probably missed.";
#   "the wtf economy - from the wtf? economy to the next economy"
#
# # Cluster (19) with (1) elements
# Exemplar:: how hbo's silicon valley built "not hotdog" with mobile tensorflow, keras & react native
#
# Others::
#   "how hbo's silicon valley built "not hotdog" with mobile tensorflow, keras & react native"
#
# # Cluster (20) with (2) elements
# Exemplar:: how does spotify know you so well? - member feature stories - medium
#
# Others::
#   "how does spotify know you so well? - member feature stories - medium";
#   "how i tracked my house movements using ibeacons. - universal mind - medium"
#
# # Cluster (21) with (1) elements
# Exemplar:: do algorithms reveal sexual orientation or just expose our stereotypes?
#
# Others::
#   "do algorithms reveal sexual orientation or just expose our stereotypes?"
#
# # Cluster (22) with (1) elements
# Exemplar:: who is going to make money in ai? part i - towards data science
#
# Others::
#   "who is going to make money in ai? part i - towards data science"
#
# # Cluster (23) with (7) elements
# Exemplar:: the fall of rnn / lstm - towards data science
#
# Others::
#   "#sneakpeek the savedroid crypto saving app -- part #1: your wish";
#   "a "weird" introduction to deep learning - towards data science";
#   "human-like machine hearing with ai (1/3) - towards data science";
#   "the big list of ds/ml interview resources - towards data science";
#   "the complete beginner's guide to chatbots - chatbots magazine";
#   "the fall of rnn / lstm - towards data science";
#   "the internet of things and the operating room of the future"
#
# # Cluster (24) with (9) elements
# Exemplar:: intuitively understanding convolutions for deep learning
#
# Others::
#   "30 amazing python projects for the past year (v.2018)";
#   "a tour of the top 10 algorithms for machine learning newbies";
#   "baidu explains how it's mastering mandarin with deep learning";
#   "how to do semantic segmentation using deep learning";
#   "intuitively understanding convolutions for deep learning";
#   "multi-index locality sensitive hashing for fun and profit";
#   "picking a gpu for deep learning - slav";
#   "siri's descendants: how intelligent assistants will evolve";
#   "your temporary instant disposable dreamhouse for the weekend"
#
# # Cluster (25) with (6) elements
# Exemplar:: an intro to machine learning for designers - ux collective
#
# Others::
#   "30 amazing machine learning projects for the past year (v.2018)";
#   "a beginner's guide to ai/ml - machine learning for humans - medium";
#   "an intro to machine learning for designers - ux collective";
#   "eleven reasons to be excited about the future of technology";
#   "how airbnb uses machine learning to detect host preferences";
#   "ultimate guide to leveraging nlp & machine learning for your chatbot"
#
# # Cluster (26) with (4) elements
# Exemplar:: must know information theory concepts in deep learning (ai)
#
# Others::
#   "a brief history of cnns in image segmentation: from r-cnn to mask r-cnn";
#   "must know information theory concepts in deep learning (ai)";
#   "python for data science: 8 concepts you may have forgotten";
#   "the 7 best data science and machine learning podcasts"
#
# # Cluster (27) with (2) elements
# Exemplar:: did google duplex just pass the turing test? - lance ulanoff - medium
#
# Others::
#   "6 tricks i learned from the otto kaggle challenge - christophe bourguignat - medium";
#   "did google duplex just pass the turing test? - lance ulanoff - medium"
#
# # Cluster (28) with (1) elements
# Exemplar:: every single machine learning course on the internet, ranked by your reviews
#
# Others::
#   "every single machine learning course on the internet, ranked by your reviews"
#
# # Cluster (29) with (5) elements
# Exemplar:: looking for a ghost in the machine - [ weird things ]
#
# Others::
#   "a brief history of cnns in image segmentation: from r-cnn to mask r-cnn";
#   "looking for a ghost in the machine - [ weird things ]";
#   "the technical trouble with humanoid robots - [ weird things ]";
#   "why do we want to build a fully fledged a.g.i.? - [ weird things ]";
#   "why you just can't black box an a.i. - [ weird things ]"
#
# # Cluster (30) with (1) elements
# Exemplar:: interview with google's alfred spector on voice search, hybrid intelligence and more
#
# Others::
#   "interview with google's alfred spector on voice search, hybrid intelligence and more"
#
# # Cluster (31) with (1) elements
# Exemplar:: becoming a cyborg should be taken gently: of modern bio-paleo-machines -- cyborgology
#
# Others::
#   "becoming a cyborg should be taken gently: of modern bio-paleo-machines -- cyborgology"
#
# # Cluster (32) with (2) elements
# Exemplar:: new to machine learning? avoid these three mistakes
#
# Others::
#   "from ballerina to ai researcher: part i - buzzrobot";
#   "new to machine learning? avoid these three mistakes"
#
# # Cluster (33) with (1) elements
# Exemplar:: i scheduled 1,019 meetings in 2012 -- and that doesn't count reschedules -- x.ai
#
# Others::
#   "i scheduled 1,019 meetings in 2012 -- and that doesn't count reschedules -- x.ai"
#
# # Cluster (34) with (1) elements
# Exemplar:: i let ibm's robot chef tell me what to cook for a week
#
# Others::
#   "i let ibm's robot chef tell me what to cook for a week"
#
# # Cluster (35) with (9) elements
# Exemplar:: how to build a multi-layered neural network in python
#
# Others::
#   "how to build a multi-layered neural network in python";
#   "how to build a neuron: exploring ai in javascript pt 1";
#   "how to build a recurrent neural network in tensorflow (1/7)";
#   "how to build a simple neural network in 9 lines of python code";
#   "how to build your own neural network from scratch in python";
#   "how to create a chatbot without coding a single line";
#   "how to create a mind: the secret of human thought revealed";
#   "how to easily automate drone-based monitoring using deep learning";
#   "how to solve 90% of nlp problems: a step-by-step guide"
#
# # Cluster (36) with (4) elements
# Exemplar:: how artificial intelligence will make technology disappear
#
# Others::
#   "artificial intelligence is humanity's rorschach test";
#   "how artificial intelligence can improve online news";
#   "how artificial intelligence will make technology disappear";
#   "using artificial intelligence to balance out customer value"
#
# # Cluster (37) with (1) elements
# Exemplar:: simple reinforcement learning with tensorflow part 0: q-learning with tables and neural networks
#
# Others::
#   "simple reinforcement learning with tensorflow part 0: q-learning with tables and neural networks"
#
# # Cluster (38) with (4) elements
# Exemplar:: understanding hinton's capsule networks. part i: intuition.
#
# Others::
#   "machine learning for humans, part 2.1: supervised learning";
#   "traveling santa problem -- an incompetent algorist's attempt";
#   "understanding capsule networks -- ai's alluring new architecture";
#   "understanding hinton's capsule networks. part i: intuition."
#
# # Cluster (39) with (1) elements
# Exemplar:: explained simply: how an ai program mastered the ancient game of go
#
# Others::
#   "explained simply: how an ai program mastered the ancient game of go"
#
# # Cluster (40) with (1) elements
# Exemplar:: 3 ways to apply latent semantic analysis on large-corpus text on macos terminal, jupyterlab, and...
#
# Others::
#   "3 ways to apply latent semantic analysis on large-corpus text on macos terminal, jupyterlab, and..."
#
# # Cluster (41) with (1) elements
# Exemplar:: o grupo de estudo em deep learning de brasilia esta planejando o proximo ciclo de encontros do...
#
# Others::
#   "o grupo de estudo em deep learning de brasilia esta planejando o proximo ciclo de encontros do..."
#
# # Cluster (42) with (9) elements
# Exemplar:: highway networks with tensorflow - jim fleming - medium
#
# Others::
#   "classifying websites with neural networks - knowledge from data: the datafiniti blog";
#   "color based object segmentation - akash shende - medium";
#   "craig: using neural networks to learn mario - nikolai savas - medium";
#   "game-changing trends to look out for with ai - wisewolf fund - medium";
#   "highway networks with tensorflow - jim fleming - medium";
#   "investing in artificial intelligence - nathan benaich - medium";
#   "loading a tensorflow graph with the c++ api - jim fleming - medium";
#   "traffic sign recognition with tensorflow - waleed abdulla - medium";
#   "why ai research loves pac-man - tommy thompson - medium"
#
# # Cluster (43) with (3) elements
# Exemplar:: simple reinforcement learning with tensorflow part 8: asynchronous actor-critic agents (a3c)
#
# Others::
#   "simple reinforcement learning with tensorflow part 4: deep q-networks and beyond";
#   "simple reinforcement learning with tensorflow part 8: asynchronous actor-critic agents (a3c)";
#   "you requested someone with a degree in this? *holds up hand*"
#
# # Cluster (44) with (2) elements
# Exemplar:: a simple deep learning model for stock price prediction using tensorflow
#
# Others::
#   "a brief history of cnns in image segmentation: from r-cnn to mask r-cnn";
#   "a simple deep learning model for stock price prediction using tensorflow"
#
# # Cluster (45) with (1) elements
# Exemplar:: the $1700 great deep learning box: assembly, setup and benchmarks
#
# Others::
#   "the $1700 great deep learning box: assembly, setup and benchmarks"
#
# # Cluster (46) with (1) elements
# Exemplar:: cheat sheets for ai, neural networks, machine learning, deep learning & big data
#
# Others::
#   "cheat sheets for ai, neural networks, machine learning, deep learning & big data"
#
# # Cluster (47) with (2) elements
# Exemplar:: thoughts after taking the deeplearning.ai courses - towards data science
#
# Others::
#   "artificial intelligence, ai in 2018 and beyond - towards data science";
#   "thoughts after taking the deeplearning.ai courses - towards data science"
#
# # Cluster (48) with (1) elements
# Exemplar:: how to build your own alphazero ai using python and keras
#
# Others::
#   "how to build your own alphazero ai using python and keras"
#
# # Cluster (49) with (2) elements
# Exemplar:: in defense of skepticism about deep learning - gary marcus - medium
#
# Others::
#   "in defense of skepticism about deep learning - gary marcus - medium";
#   "video of a neural network learning - deep learning 101 - medium"
#
# # Cluster (50) with (1) elements
# Exemplar:: how we grew from 0 to 4 million women on our fashion app, with a vertical machine learning approach
#
# Others::
#   "how we grew from 0 to 4 million women on our fashion app, with a vertical machine learning approach"
#
# # Cluster (51) with (1) elements
# Exemplar:: how you can train an ai to convert your design mockups into html and css
#
# Others::
#   "how you can train an ai to convert your design mockups into html and css"
#
# # Cluster (52) with (1) elements
# Exemplar:: blockchain is not only crappy technology but a bad vision for the future
#
# Others::
#   "blockchain is not only crappy technology but a bad vision for the future"
#
# # Cluster (53) with (1) elements
# Exemplar:: how to easily detect objects with deep learning on raspberry pi
#
# Others::
#   "how to easily detect objects with deep learning on raspberry pi"
#
# # Cluster (54) with (1) elements
# Exemplar:: the rise of the weaponized ai propaganda machine - scout: science fiction + journalism - medium
#
# Others::
#   "the rise of the weaponized ai propaganda machine - scout: science fiction + journalism - medium"
#
# # Cluster (55) with (1) elements
# Exemplar:: 37 reasons why your neural network is not working - slav
#
# Others::
#   "37 reasons why your neural network is not working - slav"
#
# # Cluster (56) with (3) elements
# Exemplar:: is there a future for innovation ? - becoming human: artificial intelligence magazine
#
# Others::
#   "i think i'm slowly turning into a cyborg - becoming human: artificial intelligence magazine";
#   "is there a future for innovation ? - becoming human: artificial intelligence magazine";
#   "turn your raspberry pi into homemade google home - becoming human: artificial intelligence magazine"
#
# # Cluster (57) with (1) elements
# Exemplar:: de la cooperation entre les hommes et les machines, pour une approche pair-a-pair de l'intelligence...
#
# Others::
#   "de la cooperation entre les hommes et les machines, pour une approche pair-a-pair de l'intelligence..."
#
# # Cluster (58) with (1) elements
# Exemplar:: what could happen if we did things right: an interview with kim stanley robinson, author of aurora
#
# Others::
#   "what could happen if we did things right: an interview with kim stanley robinson, author of aurora"
#
# # Cluster (59) with (2) elements
# Exemplar:: continuous video classification with tensorflow, inception and recurrent nets
#
# Others::
#   "continuous online video classification with tensorflow, inception and a raspberry pi";
#   "continuous video classification with tensorflow, inception and recurrent nets"
#
# # Cluster (60) with (18) elements
# Exemplar:: the future of work - oxford university - medium
#
# Others::
#   "a rock album for ai - carlos beltran - medium";
#   "adventures in narrated reality - artists and machine intelligence - medium";
#   "artwork personalization at netflix - netflix techblog - medium";
#   "building the interests platform - pinterest engineering - medium";
#   "chatbots, could we talk? - aima: ai marketing magazine - medium";
#   "digital transformation of business and society - frank diana - medium";
#   "generating stories about images - samim - medium";
#   "into the age of context - crossing the pond - medium";
#   "reinventing social sciences in the era of big data - i love experiments - medium";
#   "tensorflow tutorial-- part 1 - illia polosukhin - medium";
#   "the 5 clustering algorithms data scientists need to know";
#   "the complex language used in back propagation - kelvin li - medium";
#   "the evolution: a simple illustration - leethree on ux - medium";
#   "the future of digital banking - k2 product design - medium";
#   "the future of work - oxford university - medium";
#   "the future we wanted - leigh alexander - medium";
#   "the impossibility of intelligence explosion - francois chollet - medium";
#   "what worries me about ai - francois chollet - medium"
#
# # Cluster (61) with (1) elements
# Exemplar:: how invisible interfaces are going to transform the way we interact with computers
#
# Others::
#   "how invisible interfaces are going to transform the way we interact with computers"
#
# # Cluster (62) with (2) elements
# Exemplar:: are programmers headed toward another bursting bubble?
#
# Others::
#   "are programmers headed toward another bursting bubble?";
#   "surprise! neurons are now more complex than we thought!!"
#
# # Cluster (63) with (12) elements
# Exemplar:: exploring deepfakes - hacker noon
#
# Others::
#   "coursera vs udacity for machine learning - hacker noon";
#   "exploring deepfakes - hacker noon";
#   "formalizing indirect normativity - ai alignment";
#   "gradient descent vs coordinate descent - hacker noon";
#   "how i launched six side projects in 2017 - hacker noon";
#   "ii-psikhopat i ii-obmanshchik - hey machine learning";
#   "reinforcement learning from scratch - insight data";
#   "semantica desde informacion desestructurada - beeva labs";
#   "system architectures for personalization and recommendation";
#   "the 3 tricks that made alphago zero work - hacker noon";
#   "the new moats - greylock perspectives";
#   "the new neural internet is coming - hacker noon"
#
# # Cluster (64) with (2) elements
# Exemplar:: chatbots were the next big thing: what happened? - the startup - medium
#
# Others::
#   "chatbots were the next big thing: what happened? - the startup - medium";
#   "the beginner's guide to conversational commerce - the startup - medium"
#
# # Cluster (65) with (1) elements
# Exemplar:: you can build a neural network in javascript even if you don't really understand neural networks
#
# Others::
#   "you can build a neural network in javascript even if you don't really understand neural networks"
#
# # Cluster (66) with (1) elements
# Exemplar:: data augmentation | how to use deep learning when you have limited data -- part 2
#
# Others::
#   "data augmentation | how to use deep learning when you have limited data -- part 2"
#
# # Cluster (67) with (1) elements
# Exemplar:: multi-stream rnn, concat rnn, internal conv rnn, lag 2 rnn in tensorflow
#
# Others::
#   "multi-stream rnn, concat rnn, internal conv rnn, lag 2 rnn in tensorflow"
#
# # Cluster (68) with (2) elements
# Exemplar:: how to use noise to your advantage ? - towards data science
#
# Others::
#   "how to learn deep learning in 6 months - towards data science";
#   "how to use noise to your advantage ? - towards data science"
#
# # Cluster (69) with (7) elements
# Exemplar:: understanding activation functions in neural networks
#
# Others::
#   "a guide for time series prediction using recurrent neural networks (lstms)";
#   "distributed neural networks with gpus in the aws cloud";
#   "everything you need to know about artificial neural networks";
#   "rohan & lenny #1: neural networks & the backpropagation algorithm, explained";
#   "tensorflow dataset api for increasing training speed of neural networks";
#   "text classification using neural networks - machine learnings";
#   "understanding activation functions in neural networks"
#
# # Cluster (70) with (1) elements
# Exemplar:: from word2vec to doc2vec: an approach driven by chinese restaurant process
#
# Others::
#   "from word2vec to doc2vec: an approach driven by chinese restaurant process"
#
# # Cluster (71) with (1) elements
# Exemplar:: thanks so much for your response jared. really glad you enjoyed reading it.
#
# Others::
#   "thanks so much for your response jared. really glad you enjoyed reading it."
#
# # Cluster (72) with (2) elements
# Exemplar:: romance novels, generated by artificial intelligence
#
# Others::
#   "9 reasons why now is the time for artificial intelligence";
#   "romance novels, generated by artificial intelligence"
#
# # Cluster (73) with (14) elements
# Exemplar:: neural network architectures - towards data science
#
# Others::
#   ""wth does a neural network even learn??" -- a newcomer's dilemma";
#   "activation functions: neural networks - towards data science";
#   "an augmentation based deep neural network approach to learn human driving behavior";
#   "automated feature engineering in python - towards data science";
#   "beethoven, picasso, and artificial intelligence - towards data science";
#   "deep learning tips and tricks - towards data science";
#   "neural network architectures - towards data science";
#   "neural networks for algorithmic trading. simple time series forecasting";
#   "principal component analysis network in tensorflow with interactive code";
#   "reinforcement learning from scratch - insight data";
#   "spiking neural networks, the next generation of machine learning";
#   "the best words - towards data science";
#   "what makes a good data scientist/engineer? - towards data science";
#   "why data scientists love gaussian? - towards data science"
#
# # Cluster (74) with (1) elements
# Exemplar:: stochastic weight averaging -- a new way to get state of the art results in deep learning
#
# Others::
#   "stochastic weight averaging -- a new way to get state of the art results in deep learning"

# %% [markdown]
# #### Discussion
#
# Let's analyze the cluster results. **Notes:**
#
# - The algorithm was able to find four 75 clusters in 337 articles.
# - We compare the texts using word-level, thereby comparing each word.
#
# We cannot analyze each of the clusters because we have a lot of them. Thus, I am going to highlight just some of them.
#
# - **Cluster 4** - "machine learning is fun!" serie
# - **Cluster 6** - "artificial intelligence -- (...)" articles
# - **Cluster 25** - a serie of introduction content for begginers
# - **Cluster 35** - "how to build (...)" or "how to create (...)" articles
# - **Cluster 36** - articles about futurism in artificial intelligence
# - **Cluster 43** - articles about "reinforcement learning"
# - **Cluster 60** - "the future of (...)" articles and more futurism
# - **Cluster 73** - "neural network" articles
#
# However, we find a lot of clusters with only one element. To improve the results, it is necessary develop some Data Preprocess step before clustering.

# %% [markdown]
# #### Character-Level Analysis
#
# _The algorithm was not able to find clusters when analyzed in character-level._

# %%
texts = medium
affprop, _ = text_clustering(texts, similarity=levenshtein, word_level=False)
print_clusters(affprop, texts)
# Out:
# Did not converge
#
# ~ Number of texts:: 337
# ~ Number of clusters:: 1
# /opt/conda/lib/python3.7/site-packages/sklearn/cluster/_affinity_propagation.py:244: ConvergenceWarning: Affinity propagation did not converge, this model will not have any cluster centers.
#   "will not have any cluster centers.", ConvergenceWarning)
# 'Only few clusters - Stopped'

# %% [markdown]
# -----
# <a id="ref"></a>
# # References
#
# Additional readings about Text Clustering.
#
# - [Medium - A Friendly Introduction to Text Clustering (2020)](https://towardsdatascience.com/a-friendly-introduction-to-text-clustering-fa996bcefd04)
# - [Medium - Affinity Propagation Algorithm Explained (2019)](https://towardsdatascience.com/unsupervised-machine-learning-affinity-propagation-algorithm-explained-d1fef85f22c8)
# - [Paper - Clustering by passing messages between data points (2007)](https://www.science.org/doi/abs/10.1126/science.1136800)
# - [sklearn - Clustering text documents using k-means](https://scikit-learn.org/stable/auto_examples/text/plot_document_clustering.html)
# - [stack overflow - Clustering a long list of strings (words) into similarity groups (2020)](https://stats.stackexchange.com/questions/123060/clustering-a-long-list-of-strings-words-into-similarity-groups)
